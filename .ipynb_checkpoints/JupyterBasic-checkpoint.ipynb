# %% [markdown]
# print("hello")

# %%
5 + 3
# Out:
# 8

# %%
5 / 3
# Out:
# 1.6666666666666667

# %%
5 - 3
# Out:
# 2

# %%
5 * 3
# Out:
# 15

# %% [markdown]
# 안녕하세요

# %% [markdown]
# # Python 수업
# ## 셀에 대해서 배워봅니다.

# %% [markdown]
# - 안녕하세요
#   - 저는
#   - 누구입니다

# %%
ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 6EF2-7F90
#
#  C:\Users\dq\python_class 디렉터리
#
# 2026-05-19  오후 10:54    <DIR>          .
# 2026-05-19  오후 10:54    <DIR>          ..
# 2026-05-19  오후 10:53    <DIR>          .ipynb_checkpoints
# 2026-05-19  오후 09:58    <DIR>          .virtual_documents
# 2026-05-19  오후 10:54    <DIR>          .vscode
# 2026-05-18  오후 11:22    <DIR>          anaconda_projects
# 2026-05-19  오후 10:50             4,184 JupyterBasic.ipynb
#                1개 파일               4,184 바이트
#                6개 디렉터리  51,261,169,664 바이트 남음

# %%
pwd
# Out:
# 'C:\\Users\\dq\\python_class'

# %% [markdown]
# # 문법
